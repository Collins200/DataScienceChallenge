# %%
import pandas as pd
df=pd.read_json("C:/Users/Brightstar/Desktop/Holiday/working_with_data/water_point.json")
df
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 0          no                  community    Haruna Mohammed        year_round
# 1          no                  community     Haruna Mohmmed        year_round
# 2          no                  community    Haruna Mohammed        year_round
# 3          no                  community    Haruna Mohammed        year_round
# 4          no                  community    Haruna Mohammed        year_round
# ..        ...                        ...                ...               ...
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
# 711        no                  community                 Sa        year_round
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of     water_pay                 respondent research_asst_name water_used_season  \
# 0          no                  community    Haruna Mohammed        year_round
# 1          no                  community     Haruna Mohmmed        year_round
# 2          no                  community    Haruna Mohammed        year_round
# 3          no                  community    Haruna Mohammed        year_round
# 4          no                  community    Haruna Mohammed        year_round
# ..        ...                        ...                ...               ...
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
# 711        no                  community                 Sa        year_round
#
# ...

# %%
df.isnull()
# Out:
#      water_pay  respondent  research_asst_name  water_used_season  \
# 0        False       False               False              False
# 1        False       False               False              False
# 2        False       False               False              False
# 3        False       False               False              False
# 4        False       False               False              False
# ..         ...         ...                 ...                ...
# 707      False       False               False              False
# 708      False       False               False              False
# 709      False       False               False              False
# 710      False       False               False              False
# 711      False       False               False              False
#
#      _bamboo_dataset_id  _deleted_at  water_point_condition  _xform_id_string  \
# 0                 False         True                  False             False
# ...

# %%
# prints the column water_point_condition
water_point_condition=df[['water_point_condition']]
water_point_condition
# Out:
#     water_point_condition
# 0             functioning
# 1             functioning
# 2             functioning
# 3             functioning
# 4             functioning
# ..                    ...
# 707           functioning
# 708                broken
# 709                broken
# 710           functioning
# 711           functioning
#
# [712 rows x 1 columns]

# %%
# counts the values for each water_point_condition
val=pd.value_counts(water_point_condition.water_point_condition)
val
# Out:
# functioning           590
# broken                 40
# abandoned              36
# newly_constructed      28
# under_construction     16
# na_dn                   2
# Name: water_point_condition, dtype: int64

# %%
# counts the values for each water_point_condition and returns output in descending order
print(pd.value_counts(water_point_condition.water_point_condition,sort=True))
# Out:
# functioning           590
# broken                 40
# abandoned              36
# newly_constructed      28
# under_construction     16
# na_dn                   2
# Name: water_point_condition, dtype: int64

# %%
# QUESTION ONE 
#returns the number of functioning water_points
def number_of_functioning_water_point():
    return val['functioning']
number_of_functioning_water_point()
# Out:
# 590

# %%
# returns the total number of water_points
def number_of_water_point():
    return val.sum()
number_of_water_point()
# Out:
# 712

# %%
df.columns
# Out:
# Index(['water_pay', 'respondent', 'research_asst_name', 'water_used_season',
#        '_bamboo_dataset_id', '_deleted_at', 'water_point_condition',
#        '_xform_id_string', 'other_point_1km', '_attachments',
#        'communities_villages', 'end', 'animal_number', 'water_point_id',
#        'start', 'water_connected', 'water_manager_name', '_status',
#        'enum_id_1', 'water_lift_mechanism', 'districts_divisions', '_uuid',
#        'grid', 'date', 'formhub/uuid', 'road_available', 'water_functioning',
#        '_submission_time', 'signal', 'water_source_type', '_geolocation',
#        'water_point_image', 'water_point_geocode', 'deviceid',
#        'locations_wards', 'water_manager', 'water_developer', '_id',
#        'animal_point', 'water_mechanism_plate', 'water_lift_mechanism_type',
#        'road_type', 'water_mechanism_plate_units', 'water_mechanism_plate_no',
#        'water_not_functioning', 'water_source_type_other', 'simserial',
#        'subscriberid'],
# ...

# %%
# returns the columns(water_point_condition and communities_villages)
dataframe_3=df[['water_point_condition','communities_villages']]
dataframe_3
# Out:
#     water_point_condition communities_villages
# 0             functioning            Gumaryili
# 1             functioning            Selinvoya
# 2             functioning            Selinvoya
# 3             functioning            Selinvoya
# 4             functioning            Selinvoya
# ..                    ...                  ...
# 707           functioning                 Suik
# 708                broken              Vundema
# 709                broken              Vundema
# 710           functioning             Jiniensa
# 711           functioning                Jagsa
#
# [712 rows x 2 columns]

# %%
# returns column(communities_villages)
communities_village=df[['communities_villages']]
communities_village
# Out:
#     communities_villages
# 0              Gumaryili
# 1              Selinvoya
# 2              Selinvoya
# 3              Selinvoya
# 4              Selinvoya
# ..                   ...
# 707                 Suik
# 708              Vundema
# 709              Vundema
# 710             Jiniensa
# 711                Jagsa
#
# [712 rows x 1 columns]

# %%
# QUESTION TWO
def number_of_waterpoint_per_community():
    return communities_village.value_counts()
number_of_waterpoint_per_community()
# Out:
# communities_villages
# Kpatarigu               51
# Jagsa                   38
# Nayoku                  35
# Guuta                   32
# Nabulugu                31
#                         ..
# Garigu                   1
# Gumaryili                1
# Suik                     1
# Jiniensa                 1
# Kalaasa                  1
# Length: 65, dtype: int64

# %%
# outputs communities villages with broken waterpoints
broken_waterpoint=dataframe_3[dataframe_3.eq('broken').any(1)]
broken_waterpoint
# Out:
#     water_point_condition communities_villages
# 51                 broken               Nayoku
# 61                 broken               Nayoku
# 64                 broken               Nayoku
# 65                 broken               Nayoku
# 66                 broken               Nayoku
# 79                 broken               Nayoku
# 87                 broken                Arigu
# 97                 broken                Arigu
# 100                broken             Gbaarigu
# 102                broken             Gbaarigu
# 114                broken            Namgurima
# 120                broken            Namgurima
# 123                broken              Zukpeni
# 130                broken              Tantala
# 155                broken            Loagri_1_
# 156                broken            Loagri_1_
# 159                broken            Loagri_1_
# 163                broken            Loagri_1_
# 217                broken            Kpatarigu
# ...

# %%
# QUESTION THREE
# outputs the ranking of the communities with regards to broken_waterpoints
broken_waterpoint.value_counts()
# Out:
# water_point_condition  communities_villages
# broken                 Nayoku                  6
#                        Loagri_1_               4
#                        Kubore                  4
#                        Bandem                  2
#                        Gbaarigu                2
#                        Namgurima               2
#                        Arigu                   2
#                        Soo                     2
#                        Vundema                 2
#                        Zanwara                 2
#                        Nyankpiensa             1
#                        Luisa                   1
#                        Longsa                  1
#                        Zogsa                   1
#                        Tantala                 1
#                        Kpatarigu               1
#                        Kanwaasa                1
#                        Kaasa                   1
# ...
